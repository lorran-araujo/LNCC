# %% [markdown]
# # Notebook python criado para administrar os artigos baixados para a revisão bibliográfica.

# %% [markdown]
# Imports:

# %%
from deep_translator import GoogleTranslator
import pandas as pd
import pickle
import os
import glob

# %% [markdown]
# # Realizador de pesquisa:

# %%
def generate_search_query_woc(synonym_groups, key="TI"):

    formatted_groups = ["(" + " OR ".join(f'"{word}"' for word in group) + ")" for group in synonym_groups]
    query = " AND ".join(formatted_groups)
    
    return f"{key}=({query})"

def generate_search_query_ieee(synonym_groups, key="Document Title"):

    formatted_groups = ["(" + " OR ".join(f'"{key}":{word}' for word in group) + ")" for group in synonym_groups]
    query = " AND ".join(formatted_groups)
    
    return f"({query})"

def generate_search_query_scopus(synonym_groups, key="TITLE"):

    formatted_groups = [f"{key}(" + " OR ".join(f'"{word}"' for word in group) + ")" for group in synonym_groups]

    query = ""

    for i in range(len(formatted_groups)):
        if i == 0:
            query = formatted_groups[i]
        else:
            query = f"{query} AND {formatted_groups[i]}"
    
    return query

# %%
# synonym_groups = [
#     ["Semantic Segmentation", "Pixel-wise classification", "Dense prediction", "Pixel-level segmentation", "Pixel-classification"],
#     ["Deep Learning", "Neural Networks", "Deep", "Artificial Intelligence", "DNNs", "DL"],
#     ["Multiscale", "Multi scale", "Multi resolution", "Multi level", "Scale-space"]
# ]

synonym_groups = [
    ["Semantic Segmentation", "Pixel-wise classification", "Dense prediction", "Pixel-level segmentation", "Pixel-classification"],
    ["Deep Learning", "Neural Networks", "Deep", "Artificial Intelligence", "DNNs", "DL"],
    ["Multiscale", "Multi scale", "Multi resolution", "Multi level", "Scale-space"],
    ["Regularization", "Overfitting Reduction", "Model Generalization", "Regularity", "Regularized"]
]

key_web = ["AB"]
key_ieee = ["Abstract"]
key_scopus = ["ABS"]

print("Para buscar na Web of Science:")
for key in key_web:
    print(generate_search_query_woc(synonym_groups, key=key))
print("")

print("Para buscar na IEEE:")
for key in key_ieee:
    print(generate_search_query_ieee(synonym_groups, key=key))
print("")

print("Para buscar na Scopus:")
for key in key_scopus:
    print(generate_search_query_scopus(synonym_groups, key=key))
# Out:
# Para buscar na Web of Science:
# AB=(("Semantic Segmentation" OR "Pixel-wise classification" OR "Dense prediction" OR "Pixel-level segmentation" OR "Pixel-classification") AND ("Deep Learning" OR "Neural Networks" OR "Deep" OR "Artificial Intelligence" OR "DNNs" OR "DL") AND ("Multiscale" OR "Multi scale" OR "Multi resolution" OR "Multi level" OR "Scale-space") AND ("Regularization" OR "Overfitting Reduction" OR "Model Generalization" OR "Regularity" OR "Regularized"))
#
# Para buscar na IEEE:
# (("Abstract":Semantic Segmentation OR "Abstract":Pixel-wise classification OR "Abstract":Dense prediction OR "Abstract":Pixel-level segmentation OR "Abstract":Pixel-classification) AND ("Abstract":Deep Learning OR "Abstract":Neural Networks OR "Abstract":Deep OR "Abstract":Artificial Intelligence OR "Abstract":DNNs OR "Abstract":DL) AND ("Abstract":Multiscale OR "Abstract":Multi scale OR "Abstract":Multi resolution OR "Abstract":Multi level OR "Abstract":Scale-space) AND ("Abstract":Regularization OR "Abstract":Overfitting Reduction OR "Abstract":Model Generalization OR "Abstract":Regularity OR "Abstract":Regularized))
#
# Para buscar na Scopus:
# ABS("Semantic Segmentation" OR "Pixel-wise classification" OR "Dense prediction" OR "Pixel-level segmentation" OR "Pixel-classification") AND ABS("Deep Learning" OR "Neural Networks" OR "Deep" OR "Artificial Intelligence" OR "DNNs" OR "DL") AND ABS("Multiscale" OR "Multi scale" OR "Multi resolution" OR "Multi level" OR "Scale-space") AND ABS("Regularization" OR "Overfitting Reduction" OR "Model Generalization" OR "Regularity" OR "Regularized")

# %% [markdown]
# # Primeira pesquisa:

# %% [markdown]
# ## Loading archives e preparing inital data:

# %% [markdown]
# Loading and transforming csv archives (WEB OF SCIENCE):

# %%
directory = './base/1/'

prefix = 'web'

csv_files = glob.glob(os.path.join(directory, f'{prefix}*.xls'))

dataframes = []

for file in csv_files:
    df = pd.read_excel(file)
    dataframes.append(df)

web_of_science_archives = pd.concat(dataframes, ignore_index=True)

# %%
web_of_science_archives['Base'] = 'Web of Science'

# %%
prefix = 'IEEE'

csv_files = glob.glob(os.path.join(directory, f'{prefix}*.csv'))

dataframes = []

for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

IEEE_archives = pd.concat(dataframes, ignore_index=True)

# %%
IEEE_archives['Base'] = 'IEEE'

# %%
prefix = 'scopus'

csv_files = glob.glob(os.path.join(directory, f'{prefix}*.csv'))

dataframes = []

for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

scopus_archives = pd.concat(dataframes, ignore_index=True)

# %%
scopus_archives['Base'] = 'Scopus (Elsevier)'

# %% [markdown]
# Deleting Duplicates:

# %%
web_of_science_archives = web_of_science_archives.drop_duplicates()
IEEE_archives = IEEE_archives.drop_duplicates()
scopus_archives = scopus_archives.drop_duplicates()

# %%
scopus_archives.groupby("Year").size()
# Out:
# Year
# 2017     2
# 2018     1
# 2020     4
# 2021     3
# 2022    15
# 2023     6
# 2024    10
# 2025     2
# dtype: int64

# %%
print(web_of_science_archives.columns)
print(IEEE_archives.columns)
print(scopus_archives.columns)
# Out:
# Index(['Publication Type', 'Authors', 'Book Authors', 'Book Editors',
#        'Book Group Authors', 'Author Full Names', 'Book Author Full Names',
#        'Group Authors', 'Article Title', 'Source Title', 'Book Series Title',
#        'Book Series Subtitle', 'Language', 'Document Type', 'Conference Title',
#        'Conference Date', 'Conference Location', 'Conference Sponsor',
#        'Conference Host', 'Author Keywords', 'Keywords Plus', 'Abstract',
#        'Addresses', 'Affiliations', 'Reprint Addresses', 'Email Addresses',
#        'Researcher Ids', 'ORCIDs', 'Funding Orgs', 'Funding Name Preferred',
#        'Funding Text', 'Cited References', 'Cited Reference Count',
#        'Times Cited, WoS Core', 'Times Cited, All Databases',
#        '180 Day Usage Count', 'Since 2013 Usage Count', 'Publisher',
#        'Publisher City', 'Publisher Address', 'ISSN', 'eISSN', 'ISBN',
#        'Journal Abbreviation', 'Journal ISO Abbreviation', 'Publication Date',
#        'Publication Year', 'Volume', 'Issue', 'Part Number', 'Supplement',
#        'Special Issue', 'Meeting Abstract', 'Start Page', 'End Page',
#        'Article Number', 'DOI', 'DOI Link', 'Book DOI', 'Early Access Date',
#        'Number of Pages', 'WoS Categories', 'Web of Science Index',
#        'Research Areas', 'IDS Number', 'Pubmed Id', 'Open Access Designations',
#        'Highly Cited Status', 'Hot Paper Status', 'Date of Export',
#        'UT (Unique WOS ID)', 'Web of Science Record', 'Base'],
#       dtype='object')
# Index(['Document Title', 'Authors', 'Author Affiliations', 'Publication Title',
#        'Date Added To Xplore', 'Publication Year', 'Volume', 'Issue',
#        'Start Page', 'End Page', 'Abstract', 'ISSN', 'ISBNs', 'DOI',
#        'Funding Information', 'PDF Link', 'Author Keywords', 'IEEE Terms',
#        'Mesh_Terms', 'Article Citation Count', 'Patent Citation Count',
#        'Reference Count', 'License', 'Online Date', 'Issue Date',
#        'Meeting Date', 'Publisher', 'Document Identifier', 'Base'],
#       dtype='object')
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year', 'DOI',
#        'Link', 'Abstract', 'Author Keywords', 'Publication Stage', 'Base'],
#       dtype='object')

# %%
web_of_science_archives.rename(columns={'Authors': 'Autores'}, inplace=True)
web_of_science_archives.rename(columns={'Article Title': 'Titulo'},inplace=True)
web_of_science_archives.rename(columns={'Author Keywords': "Keywords"}, inplace=True)
web_of_science_archives.rename(columns={'Conference Date': "Year"}, inplace=True)

IEEE_archives.rename(columns={'Authors': 'Autores'}, inplace=True)
IEEE_archives.rename(columns={'Document Title': 'Titulo'}, inplace = True)
IEEE_archives.rename(columns={'Author Keywords': "Keywords"}, inplace=True)
IEEE_archives.rename(columns={'Publication Year': "Year"}, inplace=True)

scopus_archives.rename(columns={'Authors': 'Autores'}, inplace=True)
scopus_archives.rename(columns={'Title': 'Titulo'}, inplace=True)
scopus_archives.rename(columns={'Author Keywords': "Keywords"}, inplace=True)

# %%
colums = ['Titulo', 'Base', 'Year', 'DOI', 'Autores', 'Keywords', 'Abstract']
data_base1 = pd.DataFrame(columns=colums)
data_base2 = pd.DataFrame(columns=colums)
data_base3 = pd.DataFrame(columns=colums)

# %%
data_base1 = web_of_science_archives[colums]
data_base2 = IEEE_archives[colums]
data_base3 = scopus_archives[colums]

data_base = pd.concat([data_base1, data_base2, data_base3], ignore_index=True)

# %%
data_base.tail()
# Out:
#                                                Titulo               Base  \
# 92  END-TO-END SEMANTIC SEGMENTATION AND BOUNDARY ...  Scopus (Elsevier)
# 93  Mixup-CAM: Weakly-supervised Semantic Segmenta...  Scopus (Elsevier)
# 94  Deep Multi-Task Learning for an Autoencoder-Re...  Scopus (Elsevier)
# 95  Semi-Supervised Semantic Segmentation Constrai...  Scopus (Elsevier)
# 96  Regularized fully convolutional networks for R...  Scopus (Elsevier)
#
#     Year                               DOI  \
# 92  2021  10.1109/IGARSS47720.2021.9555147
# 93  2020                               NaN
# 94  2022              10.3390/math10244798
# 95  2020    10.1109/ICME46284.2020.9102851
# 96  2017         10.1109/VCIP.2016.7805508
#
#                                               Autores  \
# 92  Li Q.; Zorzi S.; Shi Y.; Fraundorfer F.; Zhu X.X.
# 93  Chang Y.-T.; Wang Q.; Hung W.-C.; Piramuthu R....
# 94                           Jin G.; Chen X.; Ying L.
# 95               Li X.; He Q.; Dai S.; Wu P.; Tong W.
# 96                                     Su W.; Wang Z.
#
#                                              Keywords  \
# 92  Boundary regularization; Building; Generative ...
# 93                                                NaN
# 94  edge attention; retinal vessel segmentation; V...
# 95  Consistency regularization; Semantic segmentat...
# 96     Depth Segmentation FCN Features Regularization
#
#                                              Abstract
# 92  Building footprint generation is a vital task ...
# 93  Obtaining object response maps is one importan...
# 94  Automated segmentation of retinal blood vessel...
# 95  In this paper, we propose a self-training base...
# 96  The prospect of semantic segmentation using de...

# %%
data_base.drop_duplicates(subset=['DOI'], inplace=True)
data_base = data_base.reset_index(drop=True)

data_base.drop_duplicates(subset=['Titulo'], inplace=True)
data_base = data_base.reset_index(drop=True)

# %%
data_base.tail()
# Out:
#                                                Titulo               Base  \
# 41  Class-Aware Feature Regularization for Semanti...  Scopus (Elsevier)
# 42  Regularized Loss for Weakly Supervised Single ...  Scopus (Elsevier)
# 43  CAR: Class-Aware Regularizations for Semantic ...  Scopus (Elsevier)
# 44  Cross-consistent semantic segmentation algorit...  Scopus (Elsevier)
# 45  Regularized fully convolutional networks for R...  Scopus (Elsevier)
#
#     Year                           DOI  \
# 41  2023       10.1145/3633637.3633694
# 42  2020  10.1007/978-3-030-58526-6_21
# 43  2022  10.1007/978-3-031-19815-1_30
# 44  2022           10.11834/jig.210571
# 45  2017     10.1109/VCIP.2016.7805508
#
#                                               Autores  \
# 41       Deng Z.; Tang X.; Zhang Z.; Xie J.; Zhang W.
# 42                                         Veksler O.
# 43  Huang Y.; Kang D.; Chen L.; Zhe X.; Jia W.; Ba...
# 44            Liu L.; Zong J.; Xiao Z.; Lan H.; Qu H.
# 45                                     Su W.; Wang Z.
#
#                                              Keywords  \
# 41  class-aware regularization; inter-class variat...
# 42                                                NaN
# 43  Class-aware regularizations; Semantic segmenta...
# 44  cross-consistency training; deep learning; man...
# 45     Depth Segmentation FCN Features Regularization
#
#                                              Abstract
# 41  In this paper, to address the problem of intra...
# 42  Fully supervised semantic segmentation is high...
# 43  Recent segmentation methods, such as OCR and C...
# 44  Objective Image semantic segmentation is a pix...
# 45  The prospect of semantic segmentation using de...

# %% [markdown]
# Saving provisional pkl:

# %%
with open('./base/data_base.pkl', 'wb') as f:
    pickle.dump(data_base, f)

# %% [markdown]
# ## Managing data:

# %% [markdown]
# Loading pkl:

# %%
with open('./base/data_base.pkl', 'rb') as f:
    data_base = pickle.load(f)

# %% [markdown]
# Deleting useless articles for the search:

# %%
data_base.tail()
# Out:
#                                                Titulo               Base  \
# 41  Class-Aware Feature Regularization for Semanti...  Scopus (Elsevier)
# 42  Regularized Loss for Weakly Supervised Single ...  Scopus (Elsevier)
# 43  CAR: Class-Aware Regularizations for Semantic ...  Scopus (Elsevier)
# 44  Cross-consistent semantic segmentation algorit...  Scopus (Elsevier)
# 45  Regularized fully convolutional networks for R...  Scopus (Elsevier)
#
#     Year                           DOI  \
# 41  2023       10.1145/3633637.3633694
# 42  2020  10.1007/978-3-030-58526-6_21
# 43  2022  10.1007/978-3-031-19815-1_30
# 44  2022           10.11834/jig.210571
# 45  2017     10.1109/VCIP.2016.7805508
#
#                                               Autores  \
# 41       Deng Z.; Tang X.; Zhang Z.; Xie J.; Zhang W.
# 42                                         Veksler O.
# 43  Huang Y.; Kang D.; Chen L.; Zhe X.; Jia W.; Ba...
# 44            Liu L.; Zong J.; Xiao Z.; Lan H.; Qu H.
# 45                                     Su W.; Wang Z.
#
#                                              Keywords  \
# 41  class-aware regularization; inter-class variat...
# 42                                                NaN
# 43  Class-aware regularizations; Semantic segmenta...
# 44  cross-consistency training; deep learning; man...
# 45     Depth Segmentation FCN Features Regularization
#
#                                              Abstract
# 41  In this paper, to address the problem of intra...
# 42  Fully supervised semantic segmentation is high...
# 43  Recent segmentation methods, such as OCR and C...
# 44  Objective Image semantic segmentation is a pix...
# 45  The prospect of semantic segmentation using de...

# %%
data_base.head(57)
# Out:
#                                                Titulo               Base  \
# 0     Topological Regularization for Dense Prediction     Web of Science
# 1   Unbiased Subclass Regularization for Semi-Supe...     Web of Science
# 2   SEMI-SUPERVISED SEMANTIC SEGMENTATION CONSTRAI...     Web of Science
# 3   CARD: Semantic Segmentation With Efficient Cla...     Web of Science
# 4   Regularized Fully Convolutional Networks for R...     Web of Science
# 5   Self-regularized prototypical network for few-...     Web of Science
# 6   Class Probability Space Regularization for sem...     Web of Science
# 7   Uncertainty-aware consistency regularization f...     Web of Science
# 8   Noise-robust consistency regularization for se...     Web of Science
# 9   Consistency Regularization for Unsupervised Do...     Web of Science
# 10  Latent Space Regularization for Unsupervised D...     Web of Science
# 11  Distribution regularized self-supervised learn...     Web of Science
# 12  RankMatch: Exploring the Better Consistency Re...     Web of Science
# 13  Perturbation consistency and mutual informatio...     Web of Science
# 14  Multi-Dimensional Manifolds Consistency Regula...     Web of Science
# 15  HybridCR: Weakly-Supervised 3D Point Cloud Sem...     Web of Science
# 16  Deep multi-task learning for a geographically-...     Web of Science
# 17  Consistency Regularization Based on Masked Ima...     Web of Science
# 18  Label Propagation and Contrastive Regularizati...     Web of Science
# 19  Efficient Joint-Dimensional Search with Soluti...     Web of Science
# 20  Consistency Regularization for Semi-Supervised...     Web of Science
# 21  Towards the Target: Self-regularized Progressi...     Web of Science
# 22  Deep Multi-Task Learning for an Autoencoder-Re...     Web of Science
# 23  Semi-supervised Deep Learning via Transformati...     Web of Science
# 24  Consistency-Regularized Region-Growing Network...     Web of Science
# 25  Coarse-to-Fine Domain Adaptive Semantic Segmen...     Web of Science
# 26  Multi-Scale Classification and Contrastive Reg...     Web of Science
# 27  Semi-Supervised Remote Sensing Image Semantic ...     Web of Science
# 28  Enhancing Semi-Supervised Semantic Segmentatio...     Web of Science
# 29  Self-Attentive Local Aggregation Learning With...     Web of Science
# 30  End-to-End Semantic Segmentation and Boundary ...               IEEE
# 31  Semi-Supervised Semantic Segmentation Constrai...               IEEE
# 32  Semantic Segmentation with Generative Models: ...               IEEE
# 33  Transferring and Regularizing Prediction for S...               IEEE
# 34  Learning from Mistakes: Self-Regularizing Hier...               IEEE
# 35  Domain Adaptive Semantic Segmentation via Regi...               IEEE
# 36  BRG: Bidirectional Regularization Guidance for...               IEEE
# 37  Enhancing Lightweight Remote Sensing Semantic ...               IEEE
# 38  Learnable contextual regularization for semant...               IEEE
# 39  Consistency regularisation in varying contexts...  Scopus (Elsevier)
# 40  Image semantic segmentation based on manifold ...  Scopus (Elsevier)
# 41  Class-Aware Feature Regularization for Semanti...  Scopus (Elsevier)
# 42  Regularized Loss for Weakly Supervised Single ...  Scopus (Elsevier)
# 43  CAR: Class-Aware Regularizations for Semantic ...  Scopus (Elsevier)
# 44  Cross-consistent semantic segmentation algorit...  Scopus (Elsevier)
# 45  Regularized fully convolutional networks for R...  Scopus (Elsevier)
#
#                Year                               DOI  \
# 0   DEC 12-14, 2022     10.1109/ICMLA55696.2022.00014
# 1   JUN 18-24, 2022      10.1109/CVPR52688.2022.00973
# 2   JUL 06-10, 2020    10.1109/icme46284.2020.9102851
# 3               NaN        10.1109/TCSVT.2024.3395132
# 4   NOV 27-30, 2016                               NaN
# 5               NaN      10.1016/j.patcog.2022.109018
# 6               NaN        10.1016/j.cviu.2024.104146
# 7               NaN        10.1016/j.cviu.2022.103448
# 8               NaN      10.1016/j.neunet.2024.107041
# 9   MAY 23-27, 2022      10.1007/978-3-031-06427-2_42
# 10  JUN 19-25, 2021     10.1109/CVPRW53098.2021.00318
# 11              NaN      10.1016/j.imavis.2022.104504
# 12  JUN 16-22, 2024      10.1109/CVPR52733.2024.00326
# 13              NaN        10.1007/s00530-022-00931-9
# 14              NaN      10.1016/j.knosys.2024.112032
# 15  JUN 18-24, 2022      10.1109/CVPR52688.2022.01451
# 16              NaN   10.1016/j.isprsjprs.2018.06.007
# 17              NaN       10.1109/JSTARS.2024.3435509
# 18              NaN         10.1109/TGRS.2023.3277203
# 19              NaN        10.1007/s11263-022-01663-z
# 20              NaN       10.1109/ACCESS.2025.3526244
# 21  NOV 09-12, 2021      10.1007/978-3-031-02375-0_22
# 22              NaN              10.3390/math10244798
# 23              NaN       10.1109/JSTARS.2022.3203750
# 24              NaN          10.1109/TIP.2022.3189825
# 25  JUN 19-25, 2021      10.1109/CVPR46437.2021.00404
# 26              NaN                10.3390/rs16173319
# 27              NaN                10.3390/rs12213603
# 28              NaN                 10.3390/s24030730
# 29              NaN         10.1109/TITS.2023.3281352
# 30             2021  10.1109/IGARSS47720.2021.9555147
# 31             2020    10.1109/ICME46284.2020.9102851
# 32             2021      10.1109/CVPR46437.2021.00820
# 33             2020      10.1109/CVPR42600.2020.00964
# 34             2023          10.1109/TMM.2023.3345152
# 35             2022    10.1109/ICME52920.2022.9859793
# 36             2024  10.1109/IJCNN60899.2024.10651508
# 37             2024  10.1109/IJCNN60899.2024.10651009
# 38             2017         10.1109/ICIP.2017.8296485
# 39             2024       10.1016/j.media.2023.102997
# 40             2022               10.11834/jig.200527
# 41             2023           10.1145/3633637.3633694
# 42             2020      10.1007/978-3-030-58526-6_21
# 43             2022      10.1007/978-3-031-19815-1_30
# 44             2022               10.11834/jig.210571
# 45             2017         10.1109/VCIP.2016.7805508
#
#                                               Autores  \
# 0                                  Fu, DQ; Nelson, BJ
# 1               Guan, DY; Huang, JX; Xiao, AR; Lu, SJ
# 2             Li, XQ; He, Q; Dai, SM; Wu, P; Tong, WQ
# 3   Huang, Y; Kang, D; Chen, L; Jia, WJ; He, XJ; D...
# 4                                     Su, W; Wang, ZF
# 5                       Ding, HH; Zhang, H; Jiang, XD
# 6          Yin, JJ; Yan, S; Chen, T; Chen, Y; Yao, YZ
# 7   Zhou, QY; Feng, ZY; Gu, QQ; Cheng, GL; Lu, XQ;...
# 8   Zhang, HK; Li, HT; Zhang, XF; Yang, GY; Li, AT...
# 9                   Scherer, S; Brehm, S; Lienhart, R
# 10    Barbato, F; Toldo, M; Michieli, U; Zanuttigh, P
# 11         Iqbal, J; Rawal, H; Ha, R; Chi, YT; Ali, M
# 12                  Mai, HY; Sun, R; Zhang, TZ; Wu, F
# 13  Wu, YL; Liu, C; Chen, L; Zhao, D; Zheng, QH; Z...
# 14      Lu, YJ; Zhang, YJ; Cui, ZW; Long, W; Chen, ZY
# 15  Li, MT; Xie, Y; Shen, YH; Ke, B; Qiao, RZ; Ren...
# 16                                  Volpi, M; Tuia, D
# 17     Cai, MX; Chen, H; Zhang, T; Zhuang, Y; Chen, L
# 18  Yang, ZJ; Yan, ZY; Diao, WH; Zhang, Q; Kang, Y...
# 19  Ye, P; Li, BP; Chen, T; Fan, JY; Mei, Z; Lin, ...
# 20  Savitha, G; Girisha, S; Sughosh, P; Shetty, DK...
# 21                        Chang, J; Pang, YT; Hsu, CT
# 22                           Jin, G; Chen, X; Ying, L
# 23  Zhang, B; Zhang, YJ; Li, YS; Wan, Y; Guo, HY; ...
# 24                                 Xu, YH; Ghamisi, P
# 25                    Ma, HY; Lin, XR; Wu, ZF; Yu, YZ
# 26  Wang, JY; He, JY; Liu, Y; Chen, C; Zhang, MJ; ...
# 27      Wang, JX; Ding, CHQ; Chen, SB; He, CG; Luo, B
# 28           Xin, Y; Fan, ZD; Qi, XY; Geng, Y; Li, XM
# 29  Wang, ZP; Geng, YX; Jia, LM; Qin, Y; Chai, YY;...
# 30  Q. Li; S. Zorzi; Y. Shi; F. Fraundorfer; X. X....
# 31               X. Li; Q. He; S. Dai; P. Wu; W. Tong
# 32   D. Li; J. Yang; K. Kreis; A. Torralba; S. Fidler
# 33  Y. Zhang; Z. Qiu; T. Yao; C. -W. Ngo; D. Liu; ...
# 34                 E. Camuffo; U. Michieli; S. Milani
# 35            Q. Zhou; C. Zhuang; R. Yi; X. Lu; L. Ma
# 36           C. Rao; W. Fan; X. Yang; X. Wei; D. Zhou
# 37  Z. Chen; S. Xiao; W. Man; D. -H. Wang; Y. He; ...
# 38          J. Chu; X. Xiao; G. Meng; L. Wang; C. Pan
# 39  Bashir R.M.S.; Qaiser T.; Raza S.E.A.; Rajpoot...
# 40          Xiao Z.; Zong J.; Lan H.; Wei X.; Tang X.
# 41       Deng Z.; Tang X.; Zhang Z.; Xie J.; Zhang W.
# 42                                         Veksler O.
# 43  Huang Y.; Kang D.; Chen L.; Zhe X.; Jia W.; Ba...
# 44            Liu L.; Zong J.; Xiao Z.; Lan H.; Qu H.
# 45                                     Su W.; Wang Z.
#
#                                              Keywords  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  semantic segmentation;boundary regularization;...
# 31  Semi-supervised learning;semantic segmentation...
# 32                                                NaN
# 33                                                NaN
# 34  Point Clouds;Semantic Segmentation;Representat...
# 35  Domain Adaptation;Semantic Segmen-tation;Contr...
# 36  Self-training;Semantic Segmentation;Unsupervis...
# 37  semantic segmentation;remote sensing image;lig...
# 38  Deep convolutional neural networks;Semantic se...
# 39  Computational pathology; Contrastive learning;...
# 40  Capture of contextual information; Deep learni...
# 41  class-aware regularization; inter-class variat...
# 42                                                NaN
# 43  Class-aware regularizations; Semantic segmenta...
# 44  cross-consistency training; deep learning; man...
# 45     Depth Segmentation FCN Features Regularization
#
#                                              Abstract
# 0   Dense prediction tasks such as depth perceptio...
# 1   Semi-supervised semantic segmentation learns f...
# 2   In this paper, we propose a self-training base...
# 3   Semantic segmentation has recently achieved no...
# 4   The prospect of semantic segmentation using de...
# 5   The deep CNNs in image semantic segmentation t...
# 6   Semantic segmentation achieves fine-grained sc...
# 7   Unsupervised domain adaptation (UDA) aims to a...
# 8   The essential of semi-supervised semantic segm...
# 9   Unsupervised domain adaptation is a promising ...
# 10  Deep convolutional neural networks for semanti...
# 11  This paper proposes a novel pixel-level distri...
# 12  The key lie in semi-supervised semantic segmen...
# 13  Recent semi-supervised learning has attracted ...
# 14  Semi -supervised semantic segmentation in remo...
# 15  To address the huge labeling cost in large-sca...
# 16  When approaching the semantic segmentation of ...
# 17  Semisupervised semantic segmentation aims to e...
# 18  Remarkable progress based on deep neural netwo...
# 19  Semantic segmentation is a popular research to...
# 20  As one of the most powerful natural catastroph...
# 21  Unsupervised domain adaptation for semantic se...
# 22  Automated segmentation of retinal blood vessel...
# 23  Deep convolutional neural networks have gotten...
# 24  Deep learning algorithms have obtained great s...
# 25  Unsupervised domain adaptation (UDA) in semant...
# 26  With the proliferation of large-scale 3D point...
# 27  Image segmentation has made great progress in ...
# 28  In the field of remote sensing technology, the...
# 29  Point cloud semantic segmentation for railway ...
# 30  Building footprint generation is a vital task ...
# 31  In this paper, we propose a self-training base...
# 32  Training deep networks with limited labeled da...
# 33  Semantic segmentation often requires a large s...
# 34  Recent advances in autonomous robotic technolo...
# 35  Unsupervised domain adaptation (UDA) for seman...
# 36  Unsupervised Domain Adaptation Semantic Segmen...
# 37  Remote sensing image semantic segmentation has...
# 38  Semantic segmentation of indoor scene images h...
# 39  Semantic segmentation of various tissue and nu...
# 40  Objective: Image semantic segmentation is one ...
# 41  In this paper, to address the problem of intra...
# 42  Fully supervised semantic segmentation is high...
# 43  Recent segmentation methods, such as OCR and C...
# 44  Objective Image semantic segmentation is a pix...
# 45  The prospect of semantic segmentation using de...

# %% [markdown]
# Descartados:
#
# 31 e 45 - repetidos \
# 40 e 44 - está em Chinês \
# 41 - não consegui acesso (ACM)

# %% [markdown]
# ## 41 artigos no final explorados

# %% [markdown]
# # Segunda pesquisa

# %% [markdown]
# ## Loading archives e preparing inital data:

# %% [markdown]
# Loading and transforming csv archives (WEB OF SCIENCE):

# %%
directory = './base/2/'

prefix = 'web'

csv_files = glob.glob(os.path.join(directory, f'{prefix}*.xls'))

dataframes = []

for file in csv_files:
    df = pd.read_excel(file)
    dataframes.append(df)

web_of_science_archives = pd.concat(dataframes, ignore_index=True)

# %%
web_of_science_archives['Base'] = 'Web of Science'

# %%
prefix = 'IEEE'

csv_files = glob.glob(os.path.join(directory, f'{prefix}*.csv'))

dataframes = []

for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

IEEE_archives = pd.concat(dataframes, ignore_index=True)

# %%
IEEE_archives['Base'] = 'IEEE'

# %%
prefix = 'scopus'

csv_files = glob.glob(os.path.join(directory, f'{prefix}*.csv'))

dataframes = []

for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

scopus_archives = pd.concat(dataframes, ignore_index=True)

# %%
scopus_archives['Base'] = 'Scopus (Elsevier)'

# %% [markdown]
# Deleting Duplicates:

# %%
web_of_science_archives = web_of_science_archives.drop_duplicates()
IEEE_archives = IEEE_archives.drop_duplicates()
scopus_archives = scopus_archives.drop_duplicates()

# %%
scopus_archives.groupby("Year").size()
# Out:
# Year
# 2017    1
# 2018    2
# 2019    2
# 2020    3
# 2021    3
# 2022    2
# 2023    4
# 2024    1
# 2025    1
# dtype: int64

# %%
web_of_science_archives.rename(columns={'Authors': 'Autores'}, inplace=True)
web_of_science_archives.rename(columns={'Article Title': 'Titulo'},inplace=True)
web_of_science_archives.rename(columns={'Author Keywords': "Keywords"}, inplace=True)
web_of_science_archives.rename(columns={'Conference Date': "Year"}, inplace=True)

IEEE_archives.rename(columns={'Authors': 'Autores'}, inplace=True)
IEEE_archives.rename(columns={'Document Title': 'Titulo'}, inplace = True)
IEEE_archives.rename(columns={'Author Keywords': "Keywords"}, inplace=True)
IEEE_archives.rename(columns={'Publication Year': "Year"}, inplace=True)

scopus_archives.rename(columns={'Authors': 'Autores'}, inplace=True)
scopus_archives.rename(columns={'Title': 'Titulo'}, inplace=True)
scopus_archives.rename(columns={'Author Keywords': "Keywords"}, inplace=True)

# %%
colums = ['Titulo', 'Base', 'Year', 'DOI', 'Autores', 'Keywords', 'Abstract']
data_base1 = pd.DataFrame(columns=colums)
data_base2 = pd.DataFrame(columns=colums)
data_base3 = pd.DataFrame(columns=colums)

# %%
data_base1 = web_of_science_archives[colums]
data_base2 = IEEE_archives[colums]
data_base3 = scopus_archives[colums]

second_data_base = pd.concat([data_base1, data_base2, data_base3], ignore_index=True)

# %%
second_data_base.tail()
# Out:
#                                                Titulo               Base  \
# 33  Semantic Segmentation of Road Scene Based on M...  Scopus (Elsevier)
# 34  Convolutional Neural Network-Based Multi-scale...  Scopus (Elsevier)
# 35  Deep Multi - Resolution Network for Real- Time...  Scopus (Elsevier)
# 36  Multi-scale structural analysis of proteins by...  Scopus (Elsevier)
# 37  HookNet: Multi-resolution convolutional neural...  Scopus (Elsevier)
#
#     Year                               DOI  \
# 33  2022                10.1117/12.2644695
# 34  2025       10.1007/978-3-031-72396-4_1
# 35  2023  10.1109/IJCNN54540.2023.10191758
# 36  2020     10.1093/bioinformatics/btz650
# 37  2021       10.1016/j.media.2020.101890
#
#                                               Autores  \
# 33                                    Wang L.; Yan C.
# 34                         Wang Q.; Zhao Y.; Zhang Z.
# 35            Wang Y.; Chen S.; Bian H.; Li W.; Lu Q.
# 36                           Eguchi R.R.; Huang P.-S.
# 37  van Rijthoven M.; Balkenhol M.; Siliņa K.; van...
#
#                                              Keywords  \
# 33  ASPP; Deep supervision; Dual attention module;...
# 34  MICCAI challenge; Panoramic x-ray; Tooth segme...
# 35  CNN; Lightweight Network; Real-time; Semantic ...
# 36                                                NaN
# 37  Computational pathology; Deep learning; Multi-...
#
#                                              Abstract
# 33  Aiming at the problems of inaccurate segmentat...
# 34  In this study, we propose a semantic segmentat...
# 35  Information at different resolutions plays dis...
# 36  Motivation: Recent advances in computational m...
# 37  We propose HookNet, a semantic segmentation mo...

# %%
second_data_base.drop_duplicates(subset=['DOI'], inplace=True)
second_data_base = second_data_base.reset_index(drop=True)

second_data_base.drop_duplicates(subset=['Titulo'], inplace=True)
second_data_base = second_data_base.reset_index(drop=True)

# %% [markdown]
# Saving provisional pkl:

# %%
with open('./base/second_data_base.pkl', 'wb') as f:
    pickle.dump(second_data_base, f)

# %% [markdown]
# ## Managing data:

# %% [markdown]
# Loading pkl:

# %%
with open('./base/second_data_base.pkl', 'rb') as f:
    second_data_base = pickle.load(f)

# %% [markdown]
# Deleting useless articles for the search:

# %%
second_data_base.tail()
# Out:
#                                                Titulo               Base  \
# 17  Scale-aware neural network for semantic segmen...  Scopus (Elsevier)
# 18  Butterfly network: a convolutional neural netw...  Scopus (Elsevier)
# 19  Multi-scale residual deep network for semantic...  Scopus (Elsevier)
# 20  Semantic Segmentation of Road Scene Based on M...  Scopus (Elsevier)
# 21  Convolutional Neural Network-Based Multi-scale...  Scopus (Elsevier)
#
#     Year                          DOI  \
# 17  2021           10.3390/rs13245015
# 18  2023   10.1007/s11554-023-01273-z
# 19  2020           10.3390/RS12182932
# 20  2022           10.1117/12.2644695
# 21  2025  10.1007/978-3-031-72396-4_1
#
#                                               Autores  \
# 17  Wang L.; Zhang C.; Li R.; Duan C.; Meng X.; At...
# 18  Alavianmehr M.A.; Helfroush M.S.; Danyali H.; ...
# 19                                     Wang C.; Li L.
# 20                                    Wang L.; Yan C.
# 21                         Wang Q.; Zhao Y.; Zhang Z.
#
#                                              Keywords  \
# 17  Deep convolutional neural network; Multiple sp...
# 18  Butterfly network (BF-Net); Convolutional neur...
# 19  Multiple scales; Regularizer; Residual deep en...
# 20  ASPP; Deep supervision; Dual attention module;...
# 21  MICCAI challenge; Panoramic x-ray; Tooth segme...
#
#                                              Abstract
# 17  Assigning geospatial objects with specific cat...
# 18  The detection of multi-scale pedestrians is on...
# 19  It is challenging for semantic segmentation of...
# 20  Aiming at the problems of inaccurate segmentat...
# 21  In this study, we propose a semantic segmentat...

# %%
second_data_base.iloc[9]
# Out:
# Titulo      Semantic Segmentation of Earth Observation Dat...
# Base                                           Web of Science
# Year                                          NOV 20-24, 2016
# DOI                              10.1007/978-3-319-54181-5_12
# Autores                   Audebert, N; Le Saux, B; Lefèvre, S
# Keywords                                                  NaN
# Abstract    This work investigates the use of deep fully c...
# Name: 9, dtype: object

# %% [markdown]
# 9 é livro

# %% [markdown]
# # Terceira pesquisa

# %% [markdown]
# ## Loading archives e preparing inital data:

# %% [markdown]
# Loading and transforming csv archives (WEB OF SCIENCE):

# %%
directory = './base/3/'

prefix = 'web'

csv_files = glob.glob(os.path.join(directory, f'{prefix}*.xls'))

dataframes = []

for file in csv_files:
    df = pd.read_excel(file)
    dataframes.append(df)

web_of_science_archives = pd.concat(dataframes, ignore_index=True)

# %%
web_of_science_archives['Base'] = 'Web of Science'

# %%
prefix = 'IEEE'

csv_files = glob.glob(os.path.join(directory, f'{prefix}*.csv'))

dataframes = []

for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

IEEE_archives = pd.concat(dataframes, ignore_index=True)

# %%
IEEE_archives['Base'] = 'IEEE'

# %%
prefix = 'scopus'

csv_files = glob.glob(os.path.join(directory, f'{prefix}*.csv'))

dataframes = []

for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

scopus_archives = pd.concat(dataframes, ignore_index=True)

# %%
scopus_archives['Base'] = 'Scopus (Elsevier)'

# %% [markdown]
# Deleting Duplicates:

# %%
web_of_science_archives = web_of_science_archives.drop_duplicates()
IEEE_archives = IEEE_archives.drop_duplicates()
scopus_archives = scopus_archives.drop_duplicates()

# %%
scopus_archives.groupby("Year").size()
# Out:
# Year
# 2017     3
# 2019     2
# 2020     5
# 2021    10
# 2022    13
# 2023    10
# 2024     6
# dtype: int64

# %%
web_of_science_archives.rename(columns={'Authors': 'Autores'}, inplace=True)
web_of_science_archives.rename(columns={'Article Title': 'Titulo'},inplace=True)
web_of_science_archives.rename(columns={'Author Keywords': "Keywords"}, inplace=True)
web_of_science_archives.rename(columns={'Conference Date': "Year"}, inplace=True)

IEEE_archives.rename(columns={'Authors': 'Autores'}, inplace=True)
IEEE_archives.rename(columns={'Document Title': 'Titulo'}, inplace = True)
IEEE_archives.rename(columns={'Author Keywords': "Keywords"}, inplace=True)
IEEE_archives.rename(columns={'Publication Year': "Year"}, inplace=True)

scopus_archives.rename(columns={'Authors': 'Autores'}, inplace=True)
scopus_archives.rename(columns={'Title': 'Titulo'}, inplace=True)
scopus_archives.rename(columns={'Author Keywords': "Keywords"}, inplace=True)

# %%
colums = ['Titulo', 'Base', 'Year', 'DOI', 'Autores', 'Keywords', 'Abstract']
data_base1 = pd.DataFrame(columns=colums)
data_base2 = pd.DataFrame(columns=colums)
data_base3 = pd.DataFrame(columns=colums)

# %%
data_base1 = web_of_science_archives[colums]
data_base2 = IEEE_archives[colums]
data_base3 = scopus_archives[colums]

third_data_base = pd.concat([data_base1, data_base2, data_base3], ignore_index=True)

# %%
third_data_base.tail()
# Out:
#                                                 Titulo               Base  \
# 132  Omni-Seg: A Scale-Aware Dynamic Network for Re...  Scopus (Elsevier)
# 133  9th International Conference on Image and Grap...  Scopus (Elsevier)
# 134  UAVid: A semantic segmentation dataset for UAV...  Scopus (Elsevier)
# 135  Methodology of data fusion using deep learning...  Scopus (Elsevier)
# 136  Generalizable multi-task, multi-domain deep se...  Scopus (Elsevier)
#
#      Year                              DOI  \
# 132  2023        10.1109/TBME.2023.3260739
# 133  2017                              NaN
# 134  2020  10.1016/j.isprsjprs.2020.05.009
# 135  2020      10.1109/ACCESS.2020.3031533
# 136  2022      10.1016/j.media.2022.102556
#
#                                                Autores  \
# 132  Deng R.; Liu Q.; Cui C.; Yao T.; Long J.; Asad...
# 133                                                NaN
# 134  Lyu Y.; Vosselman G.; Xia G.-S.; Yilmaz A.; Ya...
# 135  De Oliveira J.P.; Costa M.G.F.; Costa Filho C....
# 136  Boutillon A.; Conze P.-H.; Pons C.; Burdin V.;...
#
#                                               Keywords  \
# 132  image segmentation; multi-label; multi-scale; ...
# 133                                                NaN
# 134  Dataset; Deep learning; Semantic segmentation;...
# 135  Convolutional neural networks; Deep learning; ...
# 136  Attention models; Contrastive learning; Domain...
#
#                                               Abstract
# 132  Comprehensive semantic segmentation on renal p...
# 133  The proceedings contain 172 papers. The specia...
# 134  Semantic segmentation has been one of the lead...
# 135  This study proposes a methodology using deep l...
# 136  Clinical diagnosis of the pediatric musculoske...

# %%
third_data_base.drop_duplicates(subset=['DOI'], inplace=True)
third_data_base = third_data_base.reset_index(drop=True)

third_data_base.drop_duplicates(subset=['Titulo'], inplace=True)
third_data_base = third_data_base.reset_index(drop=True)

# %% [markdown]
# Saving provisional pkl:

# %%
with open('./base/third_data_base.pkl', 'wb') as f:
    pickle.dump(third_data_base, f)

# %% [markdown]
# ## Managing data:

# %% [markdown]
# Loading pkl:

# %%
with open('./base/third_data_base.pkl', 'rb') as f:
    third_data_base = pickle.load(f)

# %% [markdown]
# Deleting useless articles for the search:

# %%
third_data_base.tail()
# Out:
#                                                Titulo               Base  \
# 84  Method for image segmentation of cucumber dise...  Scopus (Elsevier)
# 85  Conditional Generative Adversarial Networks wi...  Scopus (Elsevier)
# 86  Identification of sweetpotato virus disease-in...  Scopus (Elsevier)
# 87  Multi-scale Multi-task Distillation for Increm...  Scopus (Elsevier)
# 88  Generalized Semantic Segmentation by Self-Supe...  Scopus (Elsevier)
#
#     Year                                    DOI  \
# 84  2020  10.11975/j.issn.1002-6819.2020.16.019
# 85  2020             10.1007/s11063-020-10303-x
# 86  2024              10.3389/fpls.2024.1456713
# 87  2023           10.1007/978-3-031-25066-8_20
# 88  2023               10.1609/aaai.v37i9.26280
#
#                                               Autores  \
# 84                         Zhang S.; Wang Z.; Wang Z.
# 85                      He J.; Li X.; Liu N.; Zhan S.
# 86  Ding Z.; Zeng F.; Li H.; Zheng J.; Chen J.; Ch...
# 87                           Tian M.; Yang Q.; Gao Y.
# 88                             Yang L.; Gu X.; Sun J.
#
#                                              Keywords  \
# 84  Convolutional neural networks; Disease; Image ...
# 85  Feature matching loss; Generative adversarial ...
# 86  deep learning; RGB image; semantic segmentatio...
# 87  3D medical image segmentation; Distillation; I...
# 88                                                NaN
#
#                                              Abstract
# 84  Cucumber disease leaf image segmentation is an...
# 85  Accurate prostate MR image segmentation is a n...
# 86  Introduction: Sweetpotato virus disease (SPVD)...
# 87  Automatic medical image segmentation is the co...
# 88  Deep networks trained on the source domain sho...

# %%
third_data_base.iloc[9]
# Out:
# Titulo      From image-level to pixel-level labeling: A we...
# Base                                           Web of Science
# Year                                                      NaN
# DOI                                 10.1016/j.jag.2024.104023
# Autores                   Li, BY; Gong, AD; Zhang, JM; Fu, ZX
# Keywords                                                  NaN
# Abstract    Aquaculture mapping is essential for monitorin...
# Name: 9, dtype: object
