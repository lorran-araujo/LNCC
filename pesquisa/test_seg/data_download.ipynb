# %% [markdown]
# # Imports

# %%
from natsort import natsorted
from PIL import Image
import numpy as np
import urllib.request
import tarfile
import urllib
import pickle
import cv2
import os

# %% [markdown]
# # Functions

# %%
def download_and_extract_oxford_pet_dataset(destination_folder):
    """
    Download and extract the Oxford-IIIT Pet Dataset (images and annotations).

    :param destination_folder: Path to the directory where the files will be saved and extracted.
    """

    urls = {
        "images": "https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz",
        "annotations": "https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz"
    }

    os.makedirs(destination_folder, exist_ok=True) # creating destiantion folder

    for key, url in urls.items():
        print(f"Baixando {key}...")
        file_name = os.path.join(destination_folder, url.split("/")[-1])

        urllib.request.urlretrieve(url, file_name)
        print(f"Download concluído: {file_name}")

        print(f'Extraindo {key}...')
        with tarfile.open(file_name, "r:gz") as tar:
            tar.extractall(path=destination_folder)
        print(f"Extração concluída: {file_name}")

        os.remove(file_name)
        print(f"Arquivo compactado {file_name} removido.")


def load_and_resize_images(folder_path, target_size=(256,256), mode=None):
    """
    Loads images from a folder, resizes to a fixed size and transforms into a NumPy array.
    
    :param folder_path: Path to the folder containing the images.
    :param target_size: Fixed size (width, height) to resize images.
    :param mode: 0 if images, 1 if trimaps
    :return: NumPy array with all images resized.
    """

    file_names = natsorted(os.listdir(folder_path))

    image_arrays = []
    for filename in file_names:
        file_path = os.path.join(folder_path, filename)
        try:
            if mode == 0:
                with Image.open(file_path) as img:
                    img_resized = img.resize(target_size)  # redimensiona para 300x300
                    img_array = np.array(img_resized)     # converte para array NumPy
                    
                    if len(img_array.shape) == 2:
                        img_array = np.stack([img_array] * 3, axis=-1)
                    
                    image_arrays.append(img_array)
            
            elif mode ==1:
                with Image.open(file_path) as img:
                    img = img.convert("L")  
                    
                    img_resized = img.resize(target_size, resample=Image.NEAREST)
                    
                    trimap_array = np.array(img_resized)
                    
                    image_arrays.append(trimap_array)
            else:
                print(f"Mode not suported.")

        except Exception as e:
            print(f"Erro ao processar {filename}: {e}")
    
    # Verifica se todas as imagens têm a mesma forma
    shapes = [img.shape for img in image_arrays]
    if len(set(shapes)) > 1:
        print("Warning: Not all images have the same shape.")
    
    # Filtra as imagens que têm a forma correta
    if mode == 0:
        shape = 3
        correct_shape = target_size + (shape,)
    else:
        correct_shape = target_size
    
    for i,img in enumerate(image_arrays):
        if img.shape != correct_shape:
            print(f"Image {i} removed.")

    filtered_image_arrays = [img for img in image_arrays if img.shape == correct_shape]
    
    if len(filtered_image_arrays) < len(image_arrays):
        print(f"Removed {len(image_arrays) - len(filtered_image_arrays)} images with incorrect shape.")
    
    images_array = np.stack(filtered_image_arrays, axis=0)
    return images_array

def combine_classes(data_seg):
    """
    Combines classes 1 and 2 into a single class (1) and leaves the background as 0.
    
    :param annotation_path: Path to the segmentation file (trimap).
    :return: NumPy array with segmentation adjusted.
    """
    binary_annotation = []
    
    for img_seg in data_seg:
        binary_annotation.append(np.where(img_seg == 2, 0, 1))
    
    images_array = np.stack(binary_annotation, axis=0)

    return images_array

def gray_transforming(images):
    """
    Transforms image base to gray tone.

    :param data: Array of images to be preprocessed.
    """
    
    gray_images = np.array([cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) for img in images])

    return gray_images

def delete_non_abyssinian_images(folder_path):
    """
    Delete all images in the folder that do not start with 'Abyssinian'.

    :param folder_path: Path to the folder containing the images.
    """
    for filename in os.listdir(folder_path):
        if not filename.startswith("Abyssinian"):
            file_path = os.path.join(folder_path, filename)
            try:
                os.remove(file_path)
                print(f"Deleted {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")

def save_array_to_pkl(array, filename):
    """
    Save a numpy array to a .pkl file.

    :param array: Numpy array to be saved.
    :param filename: Name of the file to save the array.
    """
    with open(filename, "wb") as file:
        pickle.dump(array, file)
        print(f"Array saved to {filename}")

def delete_mat_files(folder_path):
    """
    Delete all files in the folder that have a .mat suffix.

    :param folder_path: Path to the folder containing the files.
    """
    for filename in os.listdir(folder_path):
        if filename.endswith(".mat"):
            file_path = os.path.join(folder_path, filename)
            try:
                os.remove(file_path)
                print(f"Deleted {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")

# %% [markdown]
# # Downloading and extracting images

# %%
destination_folder = "./oxford_pet_dataset"
download_and_extract_oxford_pet_dataset(destination_folder)

# Deleting non abyssian images
folder_path = ["./oxford_pet_dataset/images/", "./oxford_pet_dataset/annotations/trimaps/"]

for folder in folder_path:
    delete_non_abyssinian_images(folder)
    delete_mat_files(folder)
# Out:
# Baixando images...
# Download concluído: ./oxford_pet_dataset/images.tar.gz
# Extraindo images...
# Extração concluída: ./oxford_pet_dataset/images.tar.gz
# Arquivo compactado ./oxford_pet_dataset/images.tar.gz removido.
# Baixando annotations...
# Download concluído: ./oxford_pet_dataset/annotations.tar.gz
# Extraindo annotations...
# Extração concluída: ./oxford_pet_dataset/annotations.tar.gz
# Arquivo compactado ./oxford_pet_dataset/annotations.tar.gz removido.
# Deleted ./oxford_pet_dataset/images/Egyptian_Mau_98.jpg
# Deleted ./oxford_pet_dataset/images/Egyptian_Mau_10.jpg
# Deleted ./oxford_pet_dataset/images/beagle_15.jpg
# Deleted ./oxford_pet_dataset/images/basset_hound_56.jpg
# Deleted ./oxford_pet_dataset/images/chihuahua_199.jpg
# Deleted ./oxford_pet_dataset/images/Ragdoll_72.jpg
# Deleted ./oxford_pet_dataset/images/Siamese_181.jpg
# Deleted ./oxford_pet_dataset/images/american_bulldog_20.jpg
# Deleted ./oxford_pet_dataset/images/pug_4.jpg
# Deleted ./oxford_pet_dataset/images/Siamese_113.jpg
# Deleted ./oxford_pet_dataset/images/pug_44.jpg
# Deleted ./oxford_pet_dataset/images/havanese_29.jpg
# Deleted ./oxford_pet_dataset/images/Sphynx_53.jpg
# Deleted ./oxford_pet_dataset/images/pug_117.jpg
# Deleted ./oxford_pet_dataset/images/staffordshire_bull_terrier_123.jpg
# Deleted ./oxford_pet_dataset/images/Egyptian_Mau_202.jpg
# Deleted ./oxford_pet_dataset/images/scottish_terrier_71.jpg
# Deleted ./oxford_pet_dataset/images/german_shorthaired_156.jpg
# Deleted ./oxford_pet_dataset/images/Birman_193.jpg
# Deleted ./oxford_pet_dataset/images/Egyptian_Mau_31.jpg
# Deleted ./oxford_pet_dataset/images/beagle_88.jpg
# Deleted ./oxford_pet_dataset/images/Ragdoll_169.jpg
# Deleted ./oxford_pet_dataset/images/newfoundland_138.jpg
# Deleted ./oxford_pet_dataset/images/havanese_145.jpg
# Deleted ./oxford_pet_dataset/images/samoyed_160.jpg
# Deleted ./oxford_pet_dataset/images/shiba_inu_104.jpg
# Deleted ./oxford_pet_dataset/images/pomeranian_17.jpg
# Deleted ./oxford_pet_dataset/images/Siamese_170.jpg
# Deleted ./oxford_pet_dataset/images/Ragdoll_192.jpg
# Deleted ./oxford_pet_dataset/images/basset_hound_51.jpg
# Deleted ./oxford_pet_dataset/images/japanese_chin_188.jpg
# Deleted ./oxford_pet_dataset/images/Siamese_21.jpg
# Deleted ./oxford_pet_dataset/images/japanese_chin_21.jpg
# Deleted ./oxford_pet_dataset/images/miniature_pinscher_75.jpg
# Deleted ./oxford_pet_dataset/images/basset_hound_106.jpg
# Deleted ./oxford_pet_dataset/images/Birman_74.jpg
# Deleted ./oxford_pet_dataset/images/great_pyrenees_20.jpg
# Deleted ./oxford_pet_dataset/images/chihuahua_23.jpg
# Deleted ./oxford_pet_dataset/images/great_pyrenees_16.jpg
# Deleted ./oxford_pet_dataset/images/pug_32.jpg
# Deleted ./oxford_pet_dataset/images/Ragdoll_170.jpg
# Deleted ./oxford_pet_dataset/images/Persian_10.jpg
# Deleted ./oxford_pet_dataset/images/Birman_70.jpg
# Deleted ./oxford_pet_dataset/images/newfoundland_159.jpg
# Deleted ./oxford_pet_dataset/images/staffordshire_bull_terrier_133.jpg
# Deleted ./oxford_pet_dataset/images/British_Shorthair_90.jpg
# Deleted ./oxford_pet_dataset/images/Bengal_28.jpg
# Deleted ./oxford_pet_dataset/images/japanese_chin_2.jpg
# Deleted ./oxford_pet_dataset/images/keeshond_71.jpg
# Deleted ./oxford_pet_dataset/images/Bombay_115.jpg
# Deleted ./oxford_pet_dataset/images/Maine_Coon_54.jpg
# Deleted ./oxford_pet_dataset/images/pug_36.jpg
# Deleted ./oxford_pet_dataset/images/saint_bernard_54.jpg
# Deleted ./oxford_pet_dataset/images/Siamese_89.jpg
# Deleted ./oxford_pet_dataset/images/keeshond_193.jpg
# Deleted ./oxford_pet_dataset/images/american_bulldog_77.jpg
# Deleted ./oxford_pet_dataset/images/pug_151.jpg
# Deleted ./oxford_pet_dataset/images/Bombay_77.jpg
# Deleted ./oxford_pet_dataset/images/Birman_48.jpg
# Deleted ./oxford_pet_dataset/images/english_setter_97.jpg
# Deleted ./oxford_pet_dataset/images/Egyptian_Mau_118.jpg
# Deleted ./oxford_pet_dataset/images/boxer_152.jpg
# Deleted ./oxford_pet_dataset/images/wheaten_terrier_12.jpg
# Deleted ./oxford_pet_dataset/images/Egyptian_Mau_68.jpg
# Deleted ./oxford_pet_dataset/images/keeshond_183.jpg
# Deleted ./oxford_pet_dataset/images/Birman_177.jpg
# Deleted ./oxford_pet_dataset/images/Bengal
png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Russian_Blue_165.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._great_pyrenees_19.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._american_pit_bull_terrier_107.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/keeshond_132.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._american_bulldog_140.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._newfoundland_124.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Bombay_213.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Siamese_199.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._beagle_134.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/german_shorthaired_168.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._samoyed_139.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Egyptian_Mau_188.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._pomeranian_31.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Persian_90.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Egyptian_Mau_92.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/wheaten_terrier_196.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/yorkshire_terrier_183.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Maine_Coon_159.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Maine_Coon_82.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._miniature_pinscher_106.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Sphynx_127.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/saint_bernard_61.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Siamese_27.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._scottish_terrier_196.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._keeshond_94.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Bombay_22.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/english_cocker_spaniel_4.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._german_shorthaired_143.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/yorkshire_terrier_8.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._chihuahua_130.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Russian_Blue_106.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._wheaten_terrier_125.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/shiba_inu_204.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/yorkshire_terrier_112.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/american_pit_bull_terrier_184.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._beagle_171.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._boxer_98.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Birman_137.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/english_setter_90.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/basset_hound_65.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._saint_bernard_28.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/beagle_130.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Bengal_167.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Sphynx_237.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._japanese_chin_179.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/yorkshire_terrier_69.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Ragdoll_261.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._pomeranian_164.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._basset_hound_137.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._newfoundland_1.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/yorkshire_terrier_73.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._newfoundland_133.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._scottish_terrier_106.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Russian_Blue_185.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Siamese_93.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Abyssinian_133.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/american_bulldog_10.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/english_setter_166.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/english_cocker_spaniel_30.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._american_pit_bull_terrier_164.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Ragdoll_88.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Abyssinian_109.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._British_Shorthair_134.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._newfoundland_65.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/american_bulldog_71.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._pug_127.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._english_cocker_spaniel_31.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Bengal_25.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._boxer_24.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/samoyed_184.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Bengal_68.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Bombay_190.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Sphynx_38.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/boxer_193.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/leonberger_176.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Sphynx_193.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._great_pyrenees_104.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Bombay_122.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/japanese_chin_124.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Russian_Blue_86.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/japanese_chin_119.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/american_bulldog_69.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._British_Shorthair_173.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/german_shorthaired_6.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._english_setter_66.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Sphynx_179.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Birman_160.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._english_setter_44.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._havanese_123.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._leonberger_60.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._keeshond_100.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/beagle_3.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._german_shorthaired_16.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/beagle_85.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._newfoundland_55.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._german_shorthaired_174.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/pug_60.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._english_setter_6.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/British_Shorthair_107.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/yorkshire_terrier_107.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._Persian_117.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/Maine_Coon_253.png
# Deleted ./oxford_pet_dataset/annotations/trimaps/._British_Shorthair_102.png

# %% [markdown]
# # Loading and preprocessing images

# %%
print("Loading images...")
folder_path = "./oxford_pet_dataset/images/"
data = load_and_resize_images(folder_path, mode=0)
print("Images loaded.")

print("")

print("Loading segmentations...")
folder_path = "./oxford_pet_dataset/annotations/trimaps/"
data_tri_segmented = load_and_resize_images(folder_path, mode=1)
data_segmented = combine_classes(data_tri_segmented)
print("Segmentations loaded.")
# Out:
# Loading images...
# Warning: Not all images have the same shape.
# Image 4 removed.
# Removed 1 images with incorrect shape.
# Images loaded.
#
# Loading segmentations...
# Segmentations loaded.

# %% [markdown]
# Deleting respective segmentation:

# %%
data_segmented = np.delete(data_segmented, 4, axis=0)

# %%
print(data.shape)
print(data_segmented.shape)
# Out:
# (199, 256, 256, 3)
# (199, 256, 256)

# %% [markdown]
# # Saving in a pickle file

# %%
save_array_to_pkl(data, "data.pkl")
save_array_to_pkl(data_segmented, "data_segmented.pkl")
# Out:
# Array saved to data.pkl
# Array saved to data_segmented.pkl
